# %% [markdown]
# 1. Esperanza matemática y su relación con la media de una distribución
#
# La esperanza matemática (o valor esperado) de una variable aleatoria X es el promedio teórico de los valores que puede tomar, ponderado por sus probabilidades. Representa el valor promedio que se esperaría obtener si el experimento se repitiera un número muy grande de veces. En distribuciones de probabilidad, la esperanza coincide con la media poblacional; por ello, la esperanza se interpreta como la media de la distribución.

# %% [markdown]
# 2. Definición de varianza usando el concepto de esperanza
#
# La varianza mide qué tanto se dispersan los valores de la variable aleatoria con respecto a su media. Usando el concepto de esperanza, se define como:
#
# Var(X) = E[(X - E[X])^2]
#
# Es decir, la esperanza del cuadrado de las desviaciones respecto a la media. Otra forma equivalente es:
#
# Var(X) = E[X^2] - (E[X])^2

# %% [markdown]
# 3. Media y varianza de la distribución binomial
#
# Si X ~ Binomial(n, p):
#
# - Media: E[X] = n * p
# - Varianza: Var(X) = n * p * (1 - p)
#
#
# 4. Identificación del modelo de la distribución Normal
#
# La distribución Normal es una distribución continua que describe fenómenos donde los valores se concentran alrededor de una media y disminuyen simétricamente hacia ambos lados. Su función de densidad es:
#
# f(x) = (1 / (σ * √(2π))) * exp(-(x - μ)^2 / (2σ^2))
#
# Se denota como:
# X ~ N(μ, σ^2)

# %% [markdown]
# 5. Parámetros de la distribución normal
#
# La distribución Normal está completamente definida por dos parámetros:
#
# - μ : media (centro de la distribución)
# - σ^2 : varianza (dispersión de los datos)
#
# El parámetro σ es la desviación estándar.

# %% [markdown]
# 6. Aproximación de la binomial mediante la distribución normal
#
# Sí, la distribución binomial puede aproximarse mediante una distribución normal cuando el número de ensayos n es grande y la probabilidad p no es muy extrema. Una regla común es que la aproximación es adecuada cuando:
#
# n * p ≥ 5  y  n * (1 - p) ≥ 5
#
# En este caso, si X ~ Binomial(n, p), entonces puede aproximarse como:
#
# X ≈ N(n * p, n * p * (1 - p))
#
# En cálculos de probabilidades se recomienda aplicar la corrección de continuidad debido a que la binomial es discreta y la normal es continua.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Define parameters for the Normal distribution
mu = 0       # Mean
sigma = 1    # Standard deviation

# Generate a range of x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 200)  # Covers most of the distribution

# Calculate the PDF (Probability Density Function)
pdf = stats.norm.pdf(x, mu, sigma)

print(x)
print(pdf)
# Out:
# [-4.         -3.95979899 -3.91959799 -3.87939698 -3.83919598 -3.79899497
#  -3.75879397 -3.71859296 -3.67839196 -3.63819095 -3.59798995 -3.55778894
#  -3.51758794 -3.47738693 -3.43718593 -3.39698492 -3.35678392 -3.31658291
#  -3.27638191 -3.2361809  -3.1959799  -3.15577889 -3.11557789 -3.07537688
#  -3.03517588 -2.99497487 -2.95477387 -2.91457286 -2.87437186 -2.83417085
#  -2.79396985 -2.75376884 -2.71356784 -2.67336683 -2.63316583 -2.59296482
#  -2.55276382 -2.51256281 -2.47236181 -2.4321608  -2.3919598  -2.35175879
#  -2.31155779 -2.27135678 -2.23115578 -2.19095477 -2.15075377 -2.11055276
#  -2.07035176 -2.03015075 -1.98994975 -1.94974874 -1.90954774 -1.86934673
#  -1.82914573 -1.78894472 -1.74874372 -1.70854271 -1.66834171 -1.6281407
#  -1.5879397  -1.54773869 -1.50753769 -1.46733668 -1.42713568 -1.38693467
#  -1.34673367 -1.30653266 -1.26633166 -1.22613065 -1.18592965 -1.14572864
#  -1.10552764 -1.06532663 -1.02512563 -0.98492462 -0.94472362 -0.90452261
#  -0.86432161 -0.8241206  -0.7839196  -0.74371859 -0.70351759 -0.66331658
#  -0.62311558 -0.58291457 -0.54271357 -0.50251256 -0.46231156 -0.42211055
#  -0.38190955 -0.34170854 -0.30150754 -0.26130653 -0.22110553 -0.18090452
#  -0.14070352 -0.10050251 -0.06030151 -0.0201005   0.0201005   0.06030151
#   0.10050251  0.14070352  0.18090452  0.22110553  0.26130653  0.30150754
#   0.34170854  0.38190955  0.42211055  0.46231156  0.50251256  0.54271357
#   0.58291457  0.62311558  0.66331658  0.70351759  0.74371859  0.7839196
#   0.8241206   0.86432161  0.90452261  0.94472362  0.98492462  1.02512563
#   1.06532663  1.10552764  1.14572864  1.18592965  1.22613065  1.26633166
#   1.30653266  1.34673367  1.38693467  1.42713568  1.46733668  1.50753769
#   1.54773869  1.5879397   1.6281407   1.66834171  1.70854271  1.74874372
#   1.78894472  1.82914573  1.86934673  1.90954774  1.94974874  1.98994975
#   2.03015075  2.07035176  2.11055276  2.15075377  2.19095477  2.23115578
#   2.27135678  2.31155779  2.35175879  2.3919598   2.4321608   2.47236181
#   2.51256281  2.55276382  2.59296482  2.63316583  2.67336683  2.71356784
#   2.75376884  2.79396985  2.83417085  2.87437186  2.91457286  2.95477387
#   2.99497487  3.03517588  3.07537688  3.11557789  3.15577889  3.1959799
#   3.2361809   3.27638191  3.31658291  3.35678392  3.39698492  3.43718593
#   3.47738693  3.51758794  3.55778894  3.59798995  3.63819095  3.67839196
#   3.71859296  3.75879397  3.79899497  3.83919598  3.87939698  3.91959799
#   3.95979899  4.        ]
# [1.33830226e-04 1.57050590e-04 1.84002220e-04 2.15230929e-04
#  2.51353204e-04 2.93063883e-04 3.41144442e-04 3.96471915e-04
#  4.60028443e-04 5.32911470e-04 6.16344577e-04 7.11688942e-04
#  8.20455413e-04 9.44317154e-04 1.08512283e-03 1.24491027e-03
#  1.42592055e-03 1.63061237e-03 1.86167671e-03 2.12205153e-03
#  2.41493649e-03 2.74380743e-03 3.11243057e-03 3.52487599e-03
#  3.98553053e-03 4.49910954e-03 5.07066735e-03 5.70560631e-03
#  6.40968388e-03 7.18901761e-03 8.05008771e-03 8.99973671e-03
#  1.00451661e-02 1.11939296e-02 1.24539221e-02 1.38333654e-02
#  1.53407884e-02 1.69850033e-02 1.87750768e-02 2.07202951e-02
#  2.28301243e-02 2.51141651e-02 2.75821008e-02 3.02436403e-02
#  3.31084551e-02 3.61861097e-02 3.94859874e-02 4.30172097e-02
#  4.67885513e-02 5.08083496e-02 5.50844105e-02 5.96239098e-02
#  6.44332924e-02 6.95181688e-02 7.48832098e-02 8.05320413e-02
#  8.64671393e-02 9.26897267e-02 9.91996730e-02 1.05995397e-01
#  1.13073777e-01 1.20430065e-01 1.28057810e-01 1.35948791e-01
#  1.44092957e-01 1.52478386e-01 1.61091247e-01 1.69915787e-01
#  1.78934320e-01 1.88127243e-01 1.97473062e-01 2.06948441e-01
#  2.16528259e-01 2.26185697e-01 2.35892329e-01 2.45618247e-01
#  2.55332186e-01 2.65001680e-01 2.74593226e-01 2.84072464e-01
#  2.93404375e-01 3.02553485e-01 3.11484086e-01 3.20160458e-01
#  3.28547109e-01 3.36609009e-01 3.44311833e-01 3.51622201e-01
#  3.58507922e-01 3.64938223e-01 3.70883981e-01 3.76317944e-01
#  3.81214934e-01 3.85552046e-01 3.89308823e-01 3.92467418e-01
#  3.95012735e-01 3.96932550e-01 3.98217608e-01 3.98861696e-01
#  3.98861696e-01 3.98217608e-01 3.96932550e-01 3.95012735e-01
#  3.92467418e-01 3.89308823e-01 3.85552046e-01 3.81214934e-01
#  3.76317944e-01 3.70883981e-01 3.64938223e-01 3.58507922e-01
#  3.51622201e-01 3.44311833e-01 3.36609009e-01 3.28547109e-01
#  3.20160458e-01 3.11484086e-01 3.02553485e-01 2.93404375e-01
#  2.84072464e-01 2.74593226e-01 2.65001680e-01 2.55332186e-01
#  2.45618247e-01 2.35892329e-01 2.26185697e-01 2.16528259e-01
#  2.06948441e-01 1.97473062e-01 1.88127243e-01 1.78934320e-01
#  1.69915787e-01 1.61091247e-01 1.52478386e-01 1.44092957e-01
#  1.35948791e-01 1.28057810e-01 1.20430065e-01 1.13073777e-01
#  1.05995397e-01 9.91996730e-02 9.26897267e-02 8.64671393e-02
#  8.05320413e-02 7.48832098e-02 6.95181688e-02 6.44332924e-02
#  5.96239098e-02 5.50844105e-02 5.08083496e-02 4.67885513e-02
#  4.30172097e-02 3.94859874e-02 3.61861097e-02 3.31084551e-02
#  3.02436403e-02 2.75821008e-02 2.51141651e-02 2.28301243e-02
#  2.07202951e-02 1.87750768e-02 1.69850033e-02 1.53407884e-02
#  1.38333654e-02 1.24539221e-02 1.11939296e-02 1.00451661e-02
#  8.99973671e-03 8.05008771e-03 7.18901761e-03 6.40968388e-03
#  5.70560631e-03 5.07066735e-03 4.49910954e-03 3.98553053e-03
#  3.52487599e-03 3.11243057e-03 2.74380743e-03 2.41493649e-03
#  2.12205153e-03 1.86167671e-03 1.63061237e-03 1.42592055e-03
#  1.24491027e-03 1.08512283e-03 9.44317154e-04 8.20455413e-04
#  7.11688942e-04 6.16344577e-04 5.32911470e-04 4.60028443e-04
#  3.96471915e-04 3.41144442e-04 2.93063883e-04 2.51353204e-04
#  2.15230929e-04 1.84002220e-04 1.57050590e-04 1.33830226e-04]

# %%
# Create the plot
plt.stem(x, pdf)
plt.title(f'Normal Distribution (mu={mu}, sigma={sigma})')
plt.grid(True)
plt.show()

# %%
plt.plot(pdf)
